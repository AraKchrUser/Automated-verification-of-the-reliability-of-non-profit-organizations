# %%
# !pip install deeppavlov

# %%
# !python -m deeppavlov install rusentiment_elmo_twitter_cnn

# %%
# %config IPCompleter.use_jedi = False

# %%
# %%time
from deeppavlov import build_model, configs

model = build_model(configs.classifiers.rusentiment_elmo_twitter_cnn, download=True)
# Out:
# 2021-08-27 18:57:21.504 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/classifiers/rusentiment_v10.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/deeppavlov_data/classifiers/rusentiment_v10.tar.gz download because of matching hashes
# 2021-08-27 18:57:21.508 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /home/user/.deeppavlov/models/classifiers/rusentiment_v10/classes.dict]
# INFO:deeppavlov.core.data.simple_vocab:[loading vocabulary from /home/user/.deeppavlov/models/classifiers/rusentiment_v10/classes.dict]
# WARNING:tensorflow:From /home/user/src/py3.6/py3.6/lib/python3.6/site-packages/deeppavlov/models/embedders/elmo_embedder.py:186: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# ...

# %%
model(['В Африке воды мало, но она вкусная'])
# Out:
# ['positive']

# %%
text = ('Жизнь сейчас стремительно меняется — и для некоммерческих организаций тоже. Мы узнали у нескольких фондов, входящих во «Все вместе», как на их работе отразились пандемия коронавируса и экономический кризис, а главное — чем им можно помочь в это непростое время. Способов оказалось немало, и они собраны в этом материале. «Количество потребностей только растет» Все без исключения вынуждены перестраивать свою работу: отменять мероприятия (в том числе ярмарки и концерты, которые должны были принести пожертвования) или переводить их в онлайн-формат, реагировать на финансовые вызовы, стараться, чтобы кризис как можно меньше отразился на подопечных. Возникают проблемы с поставкой лекарств и оборудования из-за границы.   — Несмотря на то, что в России всерьез заговорили о проблеме только неделю назад мы уже наблюдаем спад количества пожертвований. Но наши дети не перестают болеть раком, они нуждаются все в той же поддержке, как неделю или месяц назад. Количество потребностей только растет, — рассказали в фонде «Подари жизнь».  Уменьшается и количество частных пожертвований, поделились в фонде «Настенька». Подопечные фонда из СНГ не могут приехать на плановые обследования. Кроме того, в связи с ростом курса евро значительно подорожало медицинское оборудование, которое фонд планировал купить. У «Дома с маяком» из-за возросшей нагрузки появились сложности с арендой офиса.  — Уже наметилась грустная тенденция — снижается число регулярных благотворительных пожертвования от частных лиц, — подтверждают в фонде «В твоих руках». — Сложно развивать проекты помощи подросткам в детских домах, когда ты не можешь прогнозировать, какой бюджет будет у фонда через месяц, через два, через три. Поэтому любое, даже самое маленькое, но регулярное пожертвование – это лучшая помощь фонду в сложный период.  Оформить регулярное пожертвование фонду, работа которого вам небезразлична, можно на сайте фонда или через платформы-агрегаторы: «Нужна помощь», «Добро Mail.ru». «Для них этот вирус 100% смертелен»  — Как же они справляются, наши ребята, стоящие в листе ожидания пересадки легких? Ведь они в такой вынужденной самоизоляции находятся месяцами, а то и годами. Сейчас каждый из нас  может почувствовать себя в их шкуре, правда только частично. Ведь у наших ребят еще и нет сил, чтобы развлечь себя рисованием, шитьем и ремонтом, нет друзей в этом чужом городе, которые хоть иногда заглянут к ним в гости.
#  ' Возникают проблемы с поставкой лекарств и оборудования из-за границы',
#  '   — Несмотря на то, что в России всерьез заговорили о проблеме только неделю назад мы уже наблюдаем спад количества пожертвований',
#  ' Но наши дети не перестают болеть раком, они нуждаются все в той же поддержке, как неделю или месяц назад',
# ...

# %%
feedback_list = []
for i in text:
    feedback = model([i])[0]
    if feedback == 'negative':
        print(i, '-neg')
    elif feedback == 'positive':
        print(i, '-pos')
    feedback_list.append(feedback)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-dd32a6022299> in <module>
#       1 feedback_list = []
#       2 for i in text:
# ----> 3     feedback = model([i])[0]
#       4     if feedback == 'negative':
#       5         print(i, '-neg')
#
# NameError: name 'model' is not defined

# %%
from collections import Counter

# %%
Counter(feedback_list).most_common()
# Out:
# [('neutral', 100), ('negative', 5)]

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 96 kB 316 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from deeppavlov import build_model, configs
# %config IPCompleter.use_jedi = False


model = build_model(configs.classifiers.rusentiment_elmo_twitter_cnn, download=False)
# Out:
# 2021-08-12 19:52:08.934 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /home/user/.deeppavlov/models/classifiers/rusentiment_v10/classes.dict]
# [nltk_data] Downloading package punkt to /home/user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     /home/user/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/user/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# WARNING:tensorflow:From /home/user/src/py3.6/py3.6/lib/python3.6/site-packages/deeppavlov/models/embedders/elmo_embedder.py:186: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# ...

# %%
def stat_pos_neg(text): 
    for i in text:
        feedback = model([i])[0]
        if feedback == 'negative':
            print(i, '-neg')
        elif feedback == 'positive':
            print(i, '-pos')
        feedback_list.append(feedback)

# %%
model(['В Африке воды мало, но она вкусная'])
# Out:
# ['positive']

# %%
len(text)
# Out:
# 48

# %%
text = ('В феврале 2020 года премьер-министр Михаил Мишустин поручил Минздраву, Минпромторгу, Минфину, Минэкономразвития и ФАС России разработать предложения об отмене ограничений «в отношении отдельных лекарственных препаратов, используемых при социально значимых заболеваниях». Проще говоря, обеспечить реальную возможность покупать для тяжело больных людей оригинальные препараты, а не дженерики, использование которых приводит к осложнениям и ухудшению результатов лечения.  Предложенные в итоге меры (Проект Постановления Правительства РФ «О внесении изменений в Постановление Правительства РФ от 30 ноября 2015 года № 1289») не решают данную проблему. В этом убеждены представители благотворительных организаций, работающих с различными тяжелыми заболеваниями. 28 мая ассоциация «Все вместе» направила в Минздрав, и в Минпромторг и в ФАС обращение с критикой предложенных мер и альтернативным предложением, которое подписали 25 НКО. – Я объясню, что правительство предлагает сделать. Короткий ответ: ничего. За три с половиной месяца правительство не придумало, что предложить. За плод тягостных раздумий и трудов и в качестве решения поставленной задачи подаются один несуществующий механизм и один давно существующий, не очень несовершенный, – говорит административный директор фонда AdVita Елена Грачева. – Еще в 2013-м вышло постановление правительства (№ 1086 от 28 ноября 2013 г.) о необходимости создать перечень лекарств-исключений из перечня. Перечня до сих пор нет,